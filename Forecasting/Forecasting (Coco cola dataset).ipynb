# %% [markdown]
# ## Problem Statement
#
# Forecast the CocaCola prices data set. Prepare a document for each model explaining
# how many dummy variables you have created and RMSE value for each model. Finally which model you will use for
# Forecasting.

# %%
# load the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load the data file

# %%
coca= pd.read_excel("CocaCola_Sales_Rawdata.xlsx")
coca
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %% [markdown]
# ### Look at the top 5 record of data

# %%
coca.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %% [markdown]
# # EDA

# %% [markdown]
# Check the various attributes of data like shape(rows and cols),columns,datatypes

# %%
coca.shape
# Out:
# (42, 2)

# %%
coca.columns.values
# Out:
# array(['Quarter', 'Sales'], dtype=object)

# %%
# checking the data types of all the columns
coca.dtypes
# Out:
# Quarter     object
# Sales      float64
# dtype: object

# %%
# check the descriptive statistics of numeric varaiable
coca.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %% [markdown]
# We can clearly seen that what are the min, median, std, max and 25%, 50%, 75% values.

# %%
coca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %% [markdown]
# No Null values. Note data type of data columns

# %% [markdown]
# # Duplicates

# %%
#Count of duplicated rows
coca.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is a no duplicate rows in the dataset.

# %%
#line plot
coca.Sales.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# There seen to be a quadratic upward tend with additive seasonality.

# %%
sns.histplot(data=coca,x='Sales',color='green')
plt.show()

# %% [markdown]
# sales count with reference to quarter

# %%
#Seperating and Aggregating the Quarters and years present in the 'Quarter' column of the original data, in order to do one hot encoding.
coca['quarters']=0
coca['Year']=0
for i in range(42):
    p=coca['Quarter'][i]
    coca['quarters'][i]=p[0:2]
    coca['Year'][i]=p[3:5
                     ]    
coca.head()
# Out:
#   Quarter        Sales quarters Year
# 0   Q1_86  1734.827000       Q1   86
# 1   Q2_86  2244.960999       Q2   86
# 2   Q3_86  2533.804993       Q3   86
# 3   Q4_86  2154.962997       Q4   86
# 4   Q1_87  1547.818996       Q1   87

# %%
#dummy variables that are created for the Quarter column with the original dataset
quater_dumies=pd.DataFrame(pd.get_dummies(coca['quarters']))
quater_dumies.head()
# Out:
#    Q1  Q2  Q3  Q4
# 0   1   0   0   0
# 1   0   1   0   0
# 2   0   0   1   0
# 3   0   0   0   1
# 4   1   0   0   0

# %%
coca=pd.concat([coca,quater_dumies],axis=1)

# %%
coca
# Out:
#    Quarter        Sales quarters Year  Q1  Q2  Q3  Q4
# 0    Q1_86  1734.827000       Q1   86   1   0   0   0
# 1    Q2_86  2244.960999       Q2   86   0   1   0   0
# 2    Q3_86  2533.804993       Q3   86   0   0   1   0
# 3    Q4_86  2154.962997       Q4   86   0   0   0   1
# 4    Q1_87  1547.818996       Q1   87   1   0   0   0
# 5    Q2_87  2104.411995       Q2   87   0   1   0   0
# 6    Q3_87  2014.362999       Q3   87   0   0   1   0
# 7    Q4_87  1991.746998       Q4   87   0   0   0   1
# 8    Q1_88  1869.049999       Q1   88   1   0   0   0
# 9    Q2_88  2313.631996       Q2   88   0   1   0   0
# 10   Q3_88  2128.320000       Q3   88   0   0   1   0
# 11   Q4_88  2026.828999       Q4   88   0   0   0   1
# 12   Q1_89  1910.603996       Q1   89   1   0   0   0
# 13   Q2_89  2331.164993       Q2   89   0   1   0   0
# 14   Q3_89  2206.549995       Q3   89   0   0   1   0
# 15   Q4_89  2173.967995       Q4   89   0   0   0   1
# 16   Q1_90  2148.278000       Q1   90   1   0   0   0
# 17   Q2_90  2739.307999       Q2   90   0   1   0   0
# 18   Q3_90  2792.753998       Q3   90   0   0   1   0
# 19   Q4_90  2556.009995       Q4   90   0   0   0   1
# 20   Q1_91  2480.973999       Q1   91   1   0   0   0
# 21   Q2_91  3039.522995       Q2   91   0   1   0   0
# 22   Q3_91  3172.115997       Q3   91   0   0   1   0
# 23   Q4_91  2879.000999       Q4   91   0   0   0   1
# 24   Q1_92  2772.000000       Q1   92   1   0   0   0
# 25   Q2_92  3550.000000       Q2   92   0   1   0   0
# 26   Q3_92  3508.000000       Q3   92   0   0   1   0
# 27   Q4_92  3243.859993       Q4   92   0   0   0   1
# 28   Q1_93  3056.000000       Q1   93   1   0   0   0
# 29   Q2_93  3899.000000       Q2   93   0   1   0   0
# 30   Q3_93  3629.000000       Q3   93   0   0   1   0
# 31   Q4_93  3373.000000       Q4   93   0   0   0   1
# 32   Q1_94  3352.000000       Q1   94   1   0   0   0
# 33   Q2_94  4342.000000       Q2   94   0   1   0   0
# 34   Q3_94  4461.000000       Q3   94   0   0   1   0
# 35   Q4_94  4017.000000       Q4   94   0   0   0   1
# 36   Q1_95  3854.000000       Q1   95   1   0   0   0
# 37   Q2_95  4936.000000       Q2   95   0   1   0   0
# 38   Q3_95  4895.000000       Q3   95   0   0   1   0
# 39   Q4_95  4333.000000       Q4   95   0   0   0   1
# 40   Q1_96  4194.000000       Q1   96   1   0   0   0
# 41   Q2_96  5253.000000       Q2   96   0   1   0   0

# %%
coca['time']=range(1,43)
coca['time_sqr']=coca['time']*coca['time']
coca['log_sales']=np.log(coca['Sales'])

# %%
coca
# Out:
#    Quarter        Sales quarters Year  Q1  Q2  Q3  Q4  time  time_sqr  \
# 0    Q1_86  1734.827000       Q1   86   1   0   0   0     1         1
# 1    Q2_86  2244.960999       Q2   86   0   1   0   0     2         4
# 2    Q3_86  2533.804993       Q3   86   0   0   1   0     3         9
# 3    Q4_86  2154.962997       Q4   86   0   0   0   1     4        16
# 4    Q1_87  1547.818996       Q1   87   1   0   0   0     5        25
# 5    Q2_87  2104.411995       Q2   87   0   1   0   0     6        36
# 6    Q3_87  2014.362999       Q3   87   0   0   1   0     7        49
# 7    Q4_87  1991.746998       Q4   87   0   0   0   1     8        64
# 8    Q1_88  1869.049999       Q1   88   1   0   0   0     9        81
# 9    Q2_88  2313.631996       Q2   88   0   1   0   0    10       100
# 10   Q3_88  2128.320000       Q3   88   0   0   1   0    11       121
# 11   Q4_88  2026.828999       Q4   88   0   0   0   1    12       144
# 12   Q1_89  1910.603996       Q1   89   1   0   0   0    13       169
# 13   Q2_89  2331.164993       Q2   89   0   1   0   0    14       196
# 14   Q3_89  2206.549995       Q3   89   0   0   1   0    15       225
# 15   Q4_89  2173.967995       Q4   89   0   0   0   1    16       256
# 16   Q1_90  2148.278000       Q1   90   1   0   0   0    17       289
# 17   Q2_90  2739.307999       Q2   90   0   1   0   0    18       324
# 18   Q3_90  2792.753998       Q3   90   0   0   1   0    19       361
# 19   Q4_90  2556.009995       Q4   90   0   0   0   1    20       400
# 20   Q1_91  2480.973999       Q1   91   1   0   0   0    21       441
# 21   Q2_91  3039.522995       Q2   91   0   1   0   0    22       484
# 22   Q3_91  3172.115997       Q3   91   0   0   1   0    23       529
# 23   Q4_91  2879.000999       Q4   91   0   0   0   1    24       576
# 24   Q1_92  2772.000000       Q1   92   1   0   0   0    25       625
# 25   Q2_92  3550.000000       Q2   92   0   1   0   0    26       676
# 26   Q3_92  3508.000000       Q3   92   0   0   1   0    27       729
# 27   Q4_92  3243.859993       Q4   92   0   0   0   1    28       784
# 28   Q1_93  3056.000000       Q1   93   1   0   0   0    29       841
# 29   Q2_93  3899.000000       Q2   93   0   1   0   0    30       900
# 30   Q3_93  3629.000000       Q3   93   0   0   1   0    31       961
# 31   Q4_93  3373.000000       Q4   93   0   0   0   1    32      1024
# 32   Q1_94  3352.000000       Q1   94   1   0   0   0    33      1089
# 33   Q2_94  4342.000000       Q2   94   0   1   0   0    34      1156
# 34   Q3_94  4461.000000       Q3   94   0   0   1   0    35      1225
# 35   Q4_94  4017.000000       Q4   94   0   0   0   1    36      1296
# 36   Q1_95  3854.000000       Q1   95   1   0   0   0    37      1369
# 37   Q2_95  4936.000000       Q2   95   0   1   0   0    38      1444
# 38   Q3_95  4895.000000       Q3   95   0   0   1   0    39      1521
# 39   Q4_95  4333.000000       Q4   95   0   0   0   1    40      1600
# 40   Q1_96  4194.000000       Q1   96   1   0   0   0    41      1681
# 41   Q2_96  5253.000000       Q2   96   0   1   0   0    42      1764
#
#     log_sales
# 0    7.458663
# 1    7.716443
# 2    7.837477
# 3    7.675529
# 4    7.344602
# 5    7.651791
# 6    7.608058
# 7    7.596767
# 8    7.533186
# 9    7.746574
# 10   7.663088
# 11   7.614228
# 12   7.555175
# 13   7.754123
# 14   7.699185
# 15   7.684309
# 16   7.672422
# 17   7.915461
# 18   7.934783
# 19   7.846203
# 20   7.816407
# 21   8.019456
# 22   8.062154
# 23   7.965199
# 24   7.927324
# 25   8.174703
# 26   8.162801
# 27   8.084519
# 28   8.024862
# 29   8.268475
# 30   8.196712
# 31   8.123558
# 32   8.117312
# 33   8.376090
# 34   8.403128
# 35   8.298291
# 36   8.256867
# 37   8.504311
# 38   8.495970
# 39   8.374015
# 40   8.341410
# 41   8.566555

# %%
plt.figure(figsize=(12,8))
heatmap_y_month = pd.pivot_table(data=coca,values="Sales",index="Year",columns="quarters",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_y_month,annot=True,fmt="g")
plt.title('Heatmap of Sales Count with Year and Quarters')
# Out:
# Text(0.5, 1.0, 'Heatmap of Sales Count with Year and Quarters')

# %%
# Boxplot for ever
plt.figure(figsize=(8,6))
plt.subplot(211)
sns.boxplot(x="quarters",y="Sales",data=coca)
plt.subplot(212)
sns.boxplot(x="Year",y="Sales",data=coca)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sales'>

# %% [markdown]
# box plot to understand the sales of all the four quarters.
# the sales of coca cola throughout the years with 4 components - Trend, Cyclic,Seasonality and Irregularity component.

# %%
sns.lineplot(x='Year',y='Sales',data=coca)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sales'>

# %% [markdown]
# Understand the past sales growth and to forecast the predictions.

# %% [markdown]
# # Splitting data

# %%
Train = coca.head(31)
Test = coca.tail(10)

# %%
sns.distplot(Train.Sales,color='green')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
np.log(Train.Sales)
# Out:
# 0     7.458663
# 1     7.716443
# 2     7.837477
# 3     7.675529
# 4     7.344602
# 5     7.651791
# 6     7.608058
# 7     7.596767
# 8     7.533186
# 9     7.746574
# 10    7.663088
# 11    7.614228
# 12    7.555175
# 13    7.754123
# 14    7.699185
# 15    7.684309
# 16    7.672422
# 17    7.915461
# 18    7.934783
# 19    7.846203
# 20    7.816407
# 21    8.019456
# 22    8.062154
# 23    7.965199
# 24    7.927324
# 25    8.174703
# 26    8.162801
# 27    8.084519
# 28    8.024862
# 29    8.268475
# 30    8.196712
# Name: Sales, dtype: float64

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(Train.Sales,lags=12)
tsa_plots.plot_pacf(Train.Sales,lags=12)
plt.show()
#Autocorrelation Factor >> uptill 6 we have good corr() above +-2 SE [Standard Error]
#Partial Autocorrelation Factor >> only 9 and 11 show some good corr() +-2 SE [Standard Error]

# %% [markdown]
# # Apply Forecasting Methods

# %%
coca
# Out:
#    Quarter        Sales quarters Year  Q1  Q2  Q3  Q4  time  time_sqr  \
# 0    Q1_86  1734.827000       Q1   86   1   0   0   0     1         1
# 1    Q2_86  2244.960999       Q2   86   0   1   0   0     2         4
# 2    Q3_86  2533.804993       Q3   86   0   0   1   0     3         9
# 3    Q4_86  2154.962997       Q4   86   0   0   0   1     4        16
# 4    Q1_87  1547.818996       Q1   87   1   0   0   0     5        25
# 5    Q2_87  2104.411995       Q2   87   0   1   0   0     6        36
# 6    Q3_87  2014.362999       Q3   87   0   0   1   0     7        49
# 7    Q4_87  1991.746998       Q4   87   0   0   0   1     8        64
# 8    Q1_88  1869.049999       Q1   88   1   0   0   0     9        81
# 9    Q2_88  2313.631996       Q2   88   0   1   0   0    10       100
# 10   Q3_88  2128.320000       Q3   88   0   0   1   0    11       121
# 11   Q4_88  2026.828999       Q4   88   0   0   0   1    12       144
# 12   Q1_89  1910.603996       Q1   89   1   0   0   0    13       169
# 13   Q2_89  2331.164993       Q2   89   0   1   0   0    14       196
# 14   Q3_89  2206.549995       Q3   89   0   0   1   0    15       225
# 15   Q4_89  2173.967995       Q4   89   0   0   0   1    16       256
# 16   Q1_90  2148.278000       Q1   90   1   0   0   0    17       289
# 17   Q2_90  2739.307999       Q2   90   0   1   0   0    18       324
# 18   Q3_90  2792.753998       Q3   90   0   0   1   0    19       361
# 19   Q4_90  2556.009995       Q4   90   0   0   0   1    20       400
# 20   Q1_91  2480.973999       Q1   91   1   0   0   0    21       441
# 21   Q2_91  3039.522995       Q2   91   0   1   0   0    22       484
# 22   Q3_91  3172.115997       Q3   91   0   0   1   0    23       529
# 23   Q4_91  2879.000999       Q4   91   0   0   0   1    24       576
# 24   Q1_92  2772.000000       Q1   92   1   0   0   0    25       625
# 25   Q2_92  3550.000000       Q2   92   0   1   0   0    26       676
# 26   Q3_92  3508.000000       Q3   92   0   0   1   0    27       729
# 27   Q4_92  3243.859993       Q4   92   0   0   0   1    28       784
# 28   Q1_93  3056.000000       Q1   93   1   0   0   0    29       841
# 29   Q2_93  3899.000000       Q2   93   0   1   0   0    30       900
# 30   Q3_93  3629.000000       Q3   93   0   0   1   0    31       961
# 31   Q4_93  3373.000000       Q4   93   0   0   0   1    32      1024
# 32   Q1_94  3352.000000       Q1   94   1   0   0   0    33      1089
# 33   Q2_94  4342.000000       Q2   94   0   1   0   0    34      1156
# 34   Q3_94  4461.000000       Q3   94   0   0   1   0    35      1225
# 35   Q4_94  4017.000000       Q4   94   0   0   0   1    36      1296
# 36   Q1_95  3854.000000       Q1   95   1   0   0   0    37      1369
# 37   Q2_95  4936.000000       Q2   95   0   1   0   0    38      1444
# 38   Q3_95  4895.000000       Q3   95   0   0   1   0    39      1521
# 39   Q4_95  4333.000000       Q4   95   0   0   0   1    40      1600
# 40   Q1_96  4194.000000       Q1   96   1   0   0   0    41      1681
# 41   Q2_96  5253.000000       Q2   96   0   1   0   0    42      1764
#
#     log_sales
# 0    7.458663
# 1    7.716443
# 2    7.837477
# 3    7.675529
# 4    7.344602
# 5    7.651791
# 6    7.608058
# 7    7.596767
# 8    7.533186
# 9    7.746574
# 10   7.663088
# 11   7.614228
# 12   7.555175
# 13   7.754123
# 14   7.699185
# 15   7.684309
# 16   7.672422
# 17   7.915461
# 18   7.934783
# 19   7.846203
# 20   7.816407
# 21   8.019456
# 22   8.062154
# 23   7.965199
# 24   7.927324
# 25   8.174703
# 26   8.162801
# 27   8.084519
# 28   8.024862
# 29   8.268475
# 30   8.196712
# 31   8.123558
# 32   8.117312
# 33   8.376090
# 34   8.403128
# 35   8.298291
# 36   8.256867
# 37   8.504311
# 38   8.495970
# 39   8.374015
# 40   8.341410
# 41   8.566555

# %%
#performance metrics 
pfm_model_bsd = dict() # For model driven
pfm_data_bsd = dict() # For Data driven

# %%
import statsmodels.formula.api as smf 

linear_model = smf.ols('Sales~time',data=coca).fit()
#pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['Month'])))
#rmse_linear = np.sqrt(np.mean((np.array(Test['Footfalls'])-np.array(pred_linear))**2))
#rmse_linear
linear_model.predict(coca.time)
# Out:
# 0     1492.151553
# 1     1565.429688
# 2     1638.707822
# 3     1711.985956
# 4     1785.264091
# 5     1858.542225
# 6     1931.820359
# 7     2005.098494
# 8     2078.376628
# 9     2151.654763
# 10    2224.932897
# 11    2298.211031
# 12    2371.489166
# 13    2444.767300
# 14    2518.045434
# 15    2591.323569
# 16    2664.601703
# 17    2737.879837
# 18    2811.157972
# 19    2884.436106
# 20    2957.714241
# 21    3030.992375
# 22    3104.270509
# 23    3177.548644
# 24    3250.826778
# 25    3324.104912
# 26    3397.383047
# 27    3470.661181
# 28    3543.939315
# 29    3617.217450
# 30    3690.495584
# 31    3763.773719
# 32    3837.051853
# 33    3910.329987
# 34    3983.608122
# 35    4056.886256
# 36    4130.164390
# 37    4203.442525
# 38    4276.720659
# 39    4349.998793
# 40    4423.276928
# 41    4496.555062
# dtype: float64

# %%
#Linear Model
linear_model = smf.ols('Sales~time',data=Train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['time'])))
rmse_linear = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_linear))**2))
pfm_model_bsd.update( {'Linear Model' : rmse_linear} )
rmse_linear
# Out:
# 742.4653093049542

# %%
#Exponential

Exp = smf.ols('log_sales~time',data=Train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(Test['time'])))
rmse_Exp = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Exp)))**2))
pfm_model_bsd.update( {'Exponential Model' : rmse_Exp} )
rmse_Exp
# Out:
# 572.3734372809034

# %%
#Quadratic 

Quad = smf.ols('Sales~time+time_sqr',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["time","time_sqr"]]))
rmse_Quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_Quad))**2))
pfm_model_bsd.update( {'Quadratic Model' : rmse_Quad} )
rmse_Quad
# Out:
# 603.1192836309805

# %%
#Additive seasonality 

add_sea = smf.ols('Sales~Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea = pd.Series(add_sea.predict(Test[['Q1','Q2','Q3','Q4']]))
rmse_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea))**2))
pfm_model_bsd.update( {'Additive seasonality' : rmse_add_sea} )
rmse_add_sea
# Out:
# 1871.7435386758373

# %%
#Additive Seasonality Quadratic 

add_sea_Quad = smf.ols('Sales~time+time_sqr+Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Q1','Q2','Q3','Q4','time','time_sqr']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea_quad))**2))
pfm_model_bsd.update( {'Additive Seasonality Quadratic' : rmse_add_sea_quad} )
rmse_add_sea_quad
# Out:
# 436.0876274370014

# %%
##Multiplicative Seasonality

Mul_sea = smf.ols('log_sales~Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
rmse_Mult_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_sea)))**2))
pfm_model_bsd.update( {'Multiplicative Seasonality' : rmse_Mult_sea} )
rmse_Mult_sea
# Out:
# 1927.1326220319681

# %%
#Multiplicative Additive Seasonality 

Mul_Add_sea = smf.ols('log_sales~time+time_sqr+Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
rmse_Mult_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_add_sea)))**2))
pfm_model_bsd.update( {'Multiplicative Additive Seasonality ' : rmse_Mult_add_sea} )
rmse_Mult_add_sea
# Out:
# 1186.0436524940392

# %%
result_model_bsd = pd.DataFrame(pfm_model_bsd.items(),columns=['MODEL', 'RMSE'])
result_model_bsd.sort_values(by=['RMSE'])
#Additive Seasonality Quadratic has the best values
# We will plot the forcasting in the evaluation part
# Out:
#                                   MODEL         RMSE
# 4        Additive Seasonality Quadratic   436.087627
# 1                     Exponential Model   572.373437
# 2                       Quadratic Model   603.119284
# 0                          Linear Model   742.465309
# 6  Multiplicative Additive Seasonality   1186.043652
# 3                  Additive seasonality  1871.743539
# 5            Multiplicative Seasonality  1927.132622

# %% [markdown]
# Model Evaluation - Additive Seasonality Quadratic

# %%
#Build the model on entire data set
model_full = smf.ols('log_sales~time+time_sqr+Q1+Q2+Q3+Q4',data=coca).fit()

# %%
pred_new  = pd.Series(model_full.predict(coca))
pred_new
# Out:
# 0     7.429241
# 1     7.655915
# 2     7.644034
# 3     7.551496
# 4     7.474669
# 5     7.704113
# 6     7.695001
# 7     7.605233
# 8     7.531176
# 9     7.763390
# 10    7.757048
# 11    7.670049
# 12    7.598762
# 13    7.833745
# 14    7.830173
# 15    7.745945
# 16    7.677427
# 17    7.915180
# 18    7.914378
# 19    7.832919
# 20    7.767171
# 21    8.007694
# 22    8.009661
# 23    7.930972
# 24    7.867994
# 25    8.111287
# 26    8.116024
# 27    8.040105
# 28    7.979896
# 29    8.225959
# 30    8.233466
# 31    8.160316
# 32    8.102878
# 33    8.351710
# 34    8.361987
# 35    8.291607
# 36    8.236938
# 37    8.488540
# 38    8.501586
# 39    8.433976
# 40    8.382077
# 41    8.636449
# dtype: float64

# %%
coca["forecasted_sales"] = pd.Series(np.exp(pred_new))

# %%
coca
# Out:
#    Quarter        Sales quarters Year  Q1  Q2  Q3  Q4  time  time_sqr  \
# 0    Q1_86  1734.827000       Q1   86   1   0   0   0     1         1
# 1    Q2_86  2244.960999       Q2   86   0   1   0   0     2         4
# 2    Q3_86  2533.804993       Q3   86   0   0   1   0     3         9
# 3    Q4_86  2154.962997       Q4   86   0   0   0   1     4        16
# 4    Q1_87  1547.818996       Q1   87   1   0   0   0     5        25
# 5    Q2_87  2104.411995       Q2   87   0   1   0   0     6        36
# 6    Q3_87  2014.362999       Q3   87   0   0   1   0     7        49
# 7    Q4_87  1991.746998       Q4   87   0   0   0   1     8        64
# 8    Q1_88  1869.049999       Q1   88   1   0   0   0     9        81
# 9    Q2_88  2313.631996       Q2   88   0   1   0   0    10       100
# 10   Q3_88  2128.320000       Q3   88   0   0   1   0    11       121
# 11   Q4_88  2026.828999       Q4   88   0   0   0   1    12       144
# 12   Q1_89  1910.603996       Q1   89   1   0   0   0    13       169
# 13   Q2_89  2331.164993       Q2   89   0   1   0   0    14       196
# 14   Q3_89  2206.549995       Q3   89   0   0   1   0    15       225
# 15   Q4_89  2173.967995       Q4   89   0   0   0   1    16       256
# 16   Q1_90  2148.278000       Q1   90   1   0   0   0    17       289
# 17   Q2_90  2739.307999       Q2   90   0   1   0   0    18       324
# 18   Q3_90  2792.753998       Q3   90   0   0   1   0    19       361
# 19   Q4_90  2556.009995       Q4   90   0   0   0   1    20       400
# 20   Q1_91  2480.973999       Q1   91   1   0   0   0    21       441
# 21   Q2_91  3039.522995       Q2   91   0   1   0   0    22       484
# 22   Q3_91  3172.115997       Q3   91   0   0   1   0    23       529
# 23   Q4_91  2879.000999       Q4   91   0   0   0   1    24       576
# 24   Q1_92  2772.000000       Q1   92   1   0   0   0    25       625
# 25   Q2_92  3550.000000       Q2   92   0   1   0   0    26       676
# 26   Q3_92  3508.000000       Q3   92   0   0   1   0    27       729
# 27   Q4_92  3243.859993       Q4   92   0   0   0   1    28       784
# 28   Q1_93  3056.000000       Q1   93   1   0   0   0    29       841
# 29   Q2_93  3899.000000       Q2   93   0   1   0   0    30       900
# 30   Q3_93  3629.000000       Q3   93   0   0   1   0    31       961
# 31   Q4_93  3373.000000       Q4   93   0   0   0   1    32      1024
# 32   Q1_94  3352.000000       Q1   94   1   0   0   0    33      1089
# 33   Q2_94  4342.000000       Q2   94   0   1   0   0    34      1156
# 34   Q3_94  4461.000000       Q3   94   0   0   1   0    35      1225
# 35   Q4_94  4017.000000       Q4   94   0   0   0   1    36      1296
# 36   Q1_95  3854.000000       Q1   95   1   0   0   0    37      1369
# 37   Q2_95  4936.000000       Q2   95   0   1   0   0    38      1444
# 38   Q3_95  4895.000000       Q3   95   0   0   1   0    39      1521
# 39   Q4_95  4333.000000       Q4   95   0   0   0   1    40      1600
# 40   Q1_96  4194.000000       Q1   96   1   0   0   0    41      1681
# 41   Q2_96  5253.000000       Q2   96   0   1   0   0    42      1764
#
#     log_sales  forecasted_sales
# 0    7.458663       1684.528757
# 1    7.716443       2113.108342
# 2    7.837477       2088.150211
# 3    7.675529       1903.588160
# 4    7.344602       1762.818162
# 5    7.651791       2217.449529
# 6    7.608058       2197.336692
# 7    7.596767       2008.680014
# 8    7.533186       1865.297774
# 9    7.746574       2352.866529
# 10   7.663088       2337.992146
# 11   7.614228       2143.187121
# 12   7.555175       1995.723617
# 13   7.754123       2524.366502
# 14   7.699185       2515.365251
# 15   7.684309       2312.176549
# 16   7.672422       2159.057408
# 17   7.915461       2738.540034
# 18   7.934783       2736.343628
# 19   7.846203       2522.280964
# 20   7.816407       2361.780608
# 21   8.019456       3003.982157
# 22   8.062154       3009.898022
# 23   7.965199       2782.130524
# 24   7.927324       2612.320650
# 25   8.174703       3331.863278
# 26   8.162801       3347.684312
# 27   8.084519       3102.938078
# 28   8.024862       2921.628440
# 29   8.268475       3736.702858
# 30   8.196712       3764.859570
# 31   8.123558       3499.292819
# 32   8.117312       3303.962066
# 33   8.376090       4237.420129
# 34   8.403128       4281.191306
# 35   8.298291       3990.240121
# 36   8.256867       3777.954211
# 37   8.504311       4858.766798
# 38   8.495970       4922.571771
# 39   8.374015       4600.757527
# 40   8.341410       4368.073088
# 41   8.566555       5633.290580

# %%
plt.plot(coca[['Sales','forecasted_sales']].reset_index(drop=True))
# Out:
# [<matplotlib.lines.Line2D at 0x1d0d987bac0>,
#  <matplotlib.lines.Line2D at 0x1d0d987bb20>]
